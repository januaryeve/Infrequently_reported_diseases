# %% [markdown]
# Infrequently Reported Notifiable Diseases
#
# https://catalog.data.gov/dataset/nndss-table-i-infrequently-reported-notifiable-diseases
#
# This notebook exists so I can play around with pulling data and ploting stuff

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel('C:/job_stuff/infrequently_reported_notifiable_diseases.xlsx')
print(data)
# Out:
#                                                 Disease  MMWR year  MMWR week  \
# 0                                               Anthrax     2018.0        1.0
# 1     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 2     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 3     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 4     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# ...                                                 ...        ...        ...
# 3388                                         Diphtheria     2018.0       49.0
# 3389                                         Diphtheria     2018.0       43.0
# 3390                                         Diphtheria     2018.0       45.0
# 3391                                         Diphtheria     2018.0       50.0
# 3392                                         Diphtheria     2018.0       48.0
#
# ...

# %% [markdown]
# It appears as though changing the original set from a csv to a xlsx file has done something funky to the formatting. Gonna try to read it as csv

# %%
data_round_2 = pd.read_csv('C:/job_stuff/infrequently_reported_notifiable_diseases.csv')
print(data_round_2)
# Out:
#                                                 Disease  MMWR year  MMWR week  \
# 0                                               Anthrax     2018.0        1.0
# 1     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 2     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 3     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 4     Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# ...                                                 ...        ...        ...
# 3388                                         Diphtheria     2018.0       49.0
# 3389                                         Diphtheria     2018.0       43.0
# 3390                                         Diphtheria     2018.0       45.0
# 3391                                         Diphtheria     2018.0       50.0
# 3392                                         Diphtheria     2018.0       48.0
#
# ...

# %% [markdown]
# Interesting. On second glance, the formatting remained constant for csv and xlsx files.
# Moving on...

# %%
data.plot(x= "MMWR week", y="Total cases reported for previous years  2017")
plt.show()

# %%
import numpy as np
data.plot.hist(x= "MMWR week", y="Total cases reported for previous years  2017")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# In this case, the histogram is a better representation of the data.

# %% [markdown]
# Now lets play with color...

# %%
data.plot.hist(x= "MMWR week", y="Total cases reported for previous years  2017", color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>
